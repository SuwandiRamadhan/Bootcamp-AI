# %% [markdown]
# # Data Collecting
# ### Web Scrapping sederhana menggunakan library beautifull sub

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup


base_url = 'https://www.detik.com/search/searchall?query='
query = 'mobil'

response = requests.get(base_url + query)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    berita_elements = soup.select('.list-content .list-content__item')

    for berita in berita_elements:
        judul = berita.select_one('.media__title').text.strip()
        url_berita = berita.select_one('a')['href']
        summary_str = berita.select_one('.media__desc')
        summary = summary_str.text.strip() if summary_str else np.nan

        print(f'Judul : {judul}')
        print(f'URL Berita : {url_berita}')
        print(f'Summary : {summary}')

else:
    print(f'Gagal memuat data \nStatus Code : {response.status_code}')
# Out:
# Judul : 3 Bersaudara Tewas Tertabrak Mobil di Rogodono Kebumen
# URL Berita : https://www.detik.com/jateng/berita/d-7911542/3-bersaudara-tewas-tertabrak-mobil-di-rogodono-kebumen
# Summary : Tiga orang kakak beradik dan keponakan yang berada salam satu motor tewas setelah tertabrak mobil di Kebumen.
# Judul : Terkunci Hampir Sejam dalam Mobil, Balita di Sukoharjo Dievakuasi Damkar
# URL Berita : https://www.detik.com/jateng/berita/d-7911088/terkunci-hampir-sejam-dalam-mobil-balita-di-sukoharjo-dievakuasi-damkar
# Summary : Petugas Damkar Sukoharjo mengevakuasi anak yang terjebak di dalam mobil. Anak berusia sekira 2 tahun itu terjabak selama 40 menit di dalam mobil.
# Judul : Aduh! Marak Lagi Modus Pencurian Pecahkan Kaca Mobil di Rest Area
# URL Berita : https://oto.detik.com/catatan-pengendara-mobil/d-7911279/aduh-marak-lagi-modus-pencurian-pecahkan-kaca-mobil-di-rest-area
# Summary : Buat detikers yang tengah melakukan perjalanan harus waspada dan hati-hati, tidak hanya saat berkendara, namun saat memarkirkan kendaraan juga perlu.
# Judul : Suka-Duka Pakai BYD Atto 3: Tonton Ini Sebelum Beli!
# URL Berita : https://20.detik.com/otobuzz/20250509-250512044/suka-duka-pakai-byd-atto-3-tonton-ini-sebelum-beli
# Summary : nan
# Judul : Pemilik Hyundai Ioniq 5 Geram, Mobil Mangkrak di Dealer Malah Hancur
# URL Berita : https://oto.detik.com/mobil-listrik/d-7911107/pemilik-hyundai-ioniq-5-geram-mobil-mangkrak-di-dealer-malah-hancur
# Summary : Pemilik Hyundai Ioniq 5 ini merasa kecewa lantaran mobilnya mangkrak di dealer selama dua bulan, sekarang malah hancur karena kecelakaan.
# Judul : Kesaksian Ibu Pengantin Korban Pembacokan: Kami Diserang Begitu Turun Mobil
# URL Berita : https://news.detik.com/berita/d-7910854/kesaksian-ibu-pengantin-korban-pembacokan-kami-diserang-begitu-turun-mobil
# Summary : Pengantin pria di Palembang, Ahmad Handa (30), dibacok dan ditembak oleh orang tak dikenal (OTK) saat hendak menikah. Ibu korban kaget atas serangan itu.
# Judul : Viral Bocah Nongol dari Sunroof Mobil Saat Melintas di Tol Surabaya-Malang
# URL Berita : https://www.detik.com/jatim/berita/d-7910853/viral-bocah-nongol-dari-sunroof-mobil-saat-melintas-di-tol-surabaya-malang
# Summary : Aksi bocah keluar dari sunroof mobilsaat melintas di tol Surabaya-Malang viral. Polisi ingatkan bahayanya yang bisa picu kecelakaan.
# Judul : Adem Banget, Lihat Kecantikan Porsche Bareng Lukisan Ansel Keaden Sutan
# URL Berita : https://oto.detik.com/oto-galeri/d-7911429/adem-banget-lihat-kecantikan-porsche-bareng-lukisan-ansel-keaden-sutan
# Summary : nan
# Judul : DP Rp 18 Juta Dapat Mobil Baru, Memang Bisa?
# URL Berita : https://oto.detik.com/mobil/d-7910744/dp-rp-18-juta-dapat-mobil-baru-memang-bisa
# Summary : Demi dongrak penjualan, berbagai produsen otomotif menerapkan berbagai strategi.
# Judul : Bule Mabuk Bawa Mobil, Tabrak Kendaraan Warga di Lampung
# URL Berita : https://www.detik.com/sumut/hukum-dan-kriminal/d-7910106/bule-mabuk-bawa-mobil-tabrak-kendaraan-warga-di-lampung
# Summary : Seorang WNA Australia, Anthony, ditangkap setelah menabrak kendaraan di Bandar Lampung saat mabuk. Polisi amankan sebelum massa mengamuk.
# Judul : Cerita Pilu Larasati Nugroho 4 Kali Kecelakaan Mobil
# URL Berita : https://hot.detik.com/celeb/d-7910173/cerita-pilu-larasati-nugroho-4-kali-kecelakaan-mobil
# Summary : Aktris Larasati Nugroho berbagi pengalaman mengejutkan tentang empat kecelakaan mobil yang dialaminya. Ia merenungkan makna di balik musibah tersebut.
# Judul : Diduga Gadaikan Mobil Warga, Oknum Polisi di Sigi Ditangkap
# URL Berita : https://www.detik.com/sumut/hukum-dan-kriminal/d-7910103/diduga-gadaikan-mobil-warga-oknum-polisi-di-sigi-ditangkap
# Summary : Oknum polisi berinisial Brigpol HS di Kabupaten Sigi, Sulawesi Tengah ditangkap di Taman Vatulemo Kota Palu. Oknum itu diduga gadaikan mobil warga yang disewa.

# %% [markdown]
# #### Kalau mau save data lebih banyak

# %%
# Kita buat function agar bisa di reuse
def get_detik_berita(base_url, query):
    response = requests.get(base_url + query)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        berita_elements = soup.select('.list-content .list-content__item')

        list_judul = []
        list_url_berita = []
        list_summary = []

        for berita in berita_elements:
            judul = berita.select_one('.media__title').text.strip()
            url_berita = berita.select_one('a')['href']
            summary_str = berita.select_one('.media__desc')
            summary = summary_str.text.strip() if summary_str else np.nan
        
        # Kita simpan ke list dengan append
        list_judul.append(judul)
        list_url_berita.append(url_berita)
        list_summary.append(summary)
    else:
        pass

    data = pd.DataFrame({
        'judul': list_judul,
        'url_berita': list_url_berita,
        'summary': list_summary
    })

    return data

# %%
df_berita_detik = get_detik_berita('https://www.detik.com/search/searchall?query=', 'mobil')

display(df_berita_detik)
# Out:
#                                                judul  \
# 0  Diduga Gadaikan Mobil Warga, Oknum Polisi di S...
#
#                                           url_berita  \
# 0  https://www.detik.com/sumut/hukum-dan-kriminal...
#
#                                              summary
# 0  Oknum polisi berinisial Brigpol HS di Kabupate...

# %%
# Multiple pages
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup


base_url = 'https://www.detik.com/search/searchall?query='
query = 'mobil'
sort_by = 'time'
page_count = 3


for page in range(1, page_count + 1):
    url = base_url + query + '&sortby=' + sort_by + '&page=' + str(page)

    response = requests.get(url)
    print('Page : ', page)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        berita_elements = soup.select('.list-content .list-content__item')

        for berita in berita_elements:
            judul = berita.select_one('.media__title').text.strip()
            url_berita = berita.select_one('a')['href']
            summary_str = berita.select_one('.media__desc')
            summary = summary_str.text.strip() if summary_str else np.nan
            date = berita.select_one('.media__date').select_one('span')['title']

            print(f'Judul : {judul}')
            print(f'URL Berita : {url_berita}')
            print(f'Summary : {summary}')
            print(f'Date : {date}')
            print('----------------------------------') 

    else:
        print(f'Gagal memuat data \nStatus Code : {response.status_code}')
# Out:
# Page :  1
# Judul : 3 Bersaudara Tewas Tertabrak Mobil di Rogodono Kebumen
# URL Berita : https://www.detik.com/jateng/berita/d-7911542/3-bersaudara-tewas-tertabrak-mobil-di-rogodono-kebumen
# Summary : Tiga orang kakak beradik dan keponakan yang berada salam satu motor tewas setelah tertabrak mobil di Kebumen.
# Date : Senin, 12 Mei  2025 20:40 WIB
# ----------------------------------
# Judul : Terkunci Hampir Sejam dalam Mobil, Balita di Sukoharjo Dievakuasi Damkar
# URL Berita : https://www.detik.com/jateng/berita/d-7911088/terkunci-hampir-sejam-dalam-mobil-balita-di-sukoharjo-dievakuasi-damkar
# Summary : Petugas Damkar Sukoharjo mengevakuasi anak yang terjebak di dalam mobil. Anak berusia sekira 2 tahun itu terjabak selama 40 menit di dalam mobil.
# Date : Senin, 12 Mei  2025 15:12 WIB
# ----------------------------------
# Judul : Aduh! Marak Lagi Modus Pencurian Pecahkan Kaca Mobil di Rest Area
# URL Berita : https://oto.detik.com/catatan-pengendara-mobil/d-7911279/aduh-marak-lagi-modus-pencurian-pecahkan-kaca-mobil-di-rest-area
# Summary : Buat detikers yang tengah melakukan perjalanan harus waspada dan hati-hati, tidak hanya saat berkendara, namun saat memarkirkan kendaraan juga perlu.
# Date : Senin, 12 Mei  2025 17:19 WIB
# ----------------------------------
# Judul : Suka-Duka Pakai BYD Atto 3: Tonton Ini Sebelum Beli!
# URL Berita : https://20.detik.com/otobuzz/20250509-250512044/suka-duka-pakai-byd-atto-3-tonton-ini-sebelum-beli
# Summary : nan
# Date : Senin, 12 Mei  2025 16:00 WIB
# ----------------------------------
# Judul : Pemilik Hyundai Ioniq 5 Geram, Mobil Mangkrak di Dealer Malah Hancur
# URL Berita : https://oto.detik.com/mobil-listrik/d-7911107/pemilik-hyundai-ioniq-5-geram-mobil-mangkrak-di-dealer-malah-hancur
# Summary : Pemilik Hyundai Ioniq 5 ini merasa kecewa lantaran mobilnya mangkrak di dealer selama dua bulan, sekarang malah hancur karena kecelakaan.
# Date : Senin, 12 Mei  2025 15:25 WIB
# ----------------------------------
# Judul : Kesaksian Ibu Pengantin Korban Pembacokan: Kami Diserang Begitu Turun Mobil
# URL Berita : https://news.detik.com/berita/d-7910854/kesaksian-ibu-pengantin-korban-pembacokan-kami-diserang-begitu-turun-mobil
# Summary : Pengantin pria di Palembang, Ahmad Handa (30), dibacok dan ditembak oleh orang tak dikenal (OTK) saat hendak menikah. Ibu korban kaget atas serangan itu.
# Date : Senin, 12 Mei  2025 12:51 WIB
# ----------------------------------
# Judul : Viral Bocah Nongol dari Sunroof Mobil Saat Melintas di Tol Surabaya-Malang
# URL Berita : https://www.detik.com/jatim/berita/d-7910853/viral-bocah-nongol-dari-sunroof-mobil-saat-melintas-di-tol-surabaya-malang
